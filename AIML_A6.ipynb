# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshita15887/Harshita_demo/blob/main/Assignment6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/gym_members_exercise_tracking.csv')

# %%
df
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
df.head()
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   56    Male         88.3        1.71      180      157           60
# 1   46  Female         74.9        1.53      179      151           66
# 2   32  Female         68.1        1.66      167      122           54
# 3   25    Male         53.2        1.70      190      164           56
# 4   38    Male         46.1        1.79      188      158           68
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.69           1313.0         Yoga            12.6
# 1                      1.30            883.0         HIIT            33.9
# 2                      1.11            677.0       Cardio            33.4
# 3                      0.59            532.0     Strength            28.8
# 4                      0.64            556.0     Strength            29.2
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# ...

# %%
df['Workout_Type']=df['Workout_Type'].replace({'Yoga':0,'HIIT':1,'Cardio':2,'Strength':3})
df['Gender']=df['Gender'].replace({'Female':0,'Male':1})
# Out:
# <ipython-input-43-b5fdb45530ca>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Workout_Type']=df['Workout_Type'].replace({'Yoga':0,'HIIT':1,'Cardio':2,'Strength':3})
# <ipython-input-43-b5fdb45530ca>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Gender']=df['Gender'].replace({'Female':0,'Male':1})

# %%
y=df['Workout_Type']
y
# Out:
# 0      0
# 1      1
# 2      2
# 3      3
# 4      3
#       ..
# 968    3
# 969    3
# 970    2
# 971    1
# 972    3
# Name: Workout_Type, Length: 973, dtype: int64

# %%
x=df.drop('Workout_Type',axis=1)
x
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56       1         88.3        1.71      180      157           60
# 1     46       0         74.9        1.53      179      151           66
# 2     32       0         68.1        1.66      167      122           54
# 3     25       1         53.2        1.70      190      164           56
# 4     38       1         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24       1         87.1        1.74      187      158           67
# 969   25       1         66.6        1.61      184      166           56
# 970   59       0         60.4        1.76      194      120           53
# 971   32       1        126.4        1.83      198      146           62
# 972   46       1         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned  Fat_Percentage  \
# ...

# %%
df.dtypes
# Out:
# Age                                int64
# Gender                             int64
# Weight (kg)                      float64
# Height (m)                       float64
# Max_BPM                            int64
# Avg_BPM                            int64
# Resting_BPM                        int64
# Session_Duration (hours)         float64
# Calories_Burned                  float64
# Workout_Type                       int64
# Fat_Percentage                   float64
# Water_Intake (liters)            float64
# Workout_Frequency (days/week)      int64
# Experience_Level                   int64
# BMI                              float64
# dtype: object

# %%
columns=['Weight (kg)','Height (m)','Session_Duration (hours)','Calories_Burned','Fat_Percentage','Water_Intake (liters)','BMI']

# %%
df[columns]=df[columns].astype(int)
df.dtypes
# Out:
# Age                              int64
# Gender                           int64
# Weight (kg)                      int64
# Height (m)                       int64
# Max_BPM                          int64
# Avg_BPM                          int64
# Resting_BPM                      int64
# Session_Duration (hours)         int64
# Calories_Burned                  int64
# Workout_Type                     int64
# Fat_Percentage                   int64
# Water_Intake (liters)            int64
# Workout_Frequency (days/week)    int64
# Experience_Level                 int64
# BMI                              int64
# dtype: object

# %%
df
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56       1           88           1      180      157           60
# 1     46       0           74           1      179      151           66
# 2     32       0           68           1      167      122           54
# 3     25       1           53           1      190      164           56
# 4     38       1           46           1      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24       1           87           1      187      158           67
# 969   25       1           66           1      184      166           56
# 970   59       0           60           1      194      120           53
# 971   32       1          126           1      198      146           62
# 972   46       1           88           1      166      146           66
#
#      Session_Duration (hours)  Calories_Burned  Workout_Type  Fat_Percentage  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
#df=pd.DataFrame(x)
df_minmax=pd.DataFrame(scaler.fit_transform(df),columns=df.columns)
df_minmax
# Out:
#           Age  Gender  Weight (kg)  Height (m)   Max_BPM   Avg_BPM  \
# 0    0.926829     1.0     0.539326         0.0  0.512821  0.755102
# 1    0.682927     0.0     0.382022         0.0  0.487179  0.632653
# 2    0.341463     0.0     0.314607         0.0  0.179487  0.040816
# 3    0.170732     1.0     0.146067         0.0  0.769231  0.897959
# 4    0.487805     1.0     0.067416         0.0  0.717949  0.775510
# ..        ...     ...          ...         ...       ...       ...
# 968  0.146341     1.0     0.528090         0.0  0.692308  0.775510
# 969  0.170732     1.0     0.292135         0.0  0.615385  0.938776
# 970  1.000000     0.0     0.224719         0.0  0.871795  0.000000
# 971  0.341463     1.0     0.966292         0.0  0.974359  0.530612
# 972  0.682927     1.0     0.539326         0.0  0.153846  0.530612
#
#      Resting_BPM  Session_Duration (hours)  Calories_Burned  Workout_Type  \
# 0       0.416667                       0.5         0.682432      0.000000
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
yp=knn.predict(x_test)
yp
# Out:
# array([2, 2, 0, 3, 2, 1, 2, 1, 3, 2, 0, 0, 0, 2, 0, 0, 2, 2, 0, 0, 0, 0,
#        0, 2, 2, 2, 3, 1, 0, 0, 3, 0, 2, 3, 1, 1, 1, 2, 2, 2, 0, 2, 3, 0,
#        0, 2, 2, 0, 1, 1, 2, 1, 3, 1, 3, 2, 0, 1, 1, 3, 0, 3, 0, 0, 1, 0,
#        3, 2, 2, 1, 3, 1, 2, 0, 0, 1, 2, 0, 0, 3, 0, 3, 1, 2, 1, 2, 1, 3,
#        0, 1, 1, 3, 2, 3, 0, 1, 3, 2, 1, 1, 2, 0, 0, 0, 2, 2, 2, 1, 0, 2,
#        2, 3, 1, 0, 2, 3, 2, 2, 1, 0, 0, 0, 2, 0, 0, 3, 0, 3, 0, 1, 2, 0,
#        2, 1, 3, 1, 2, 3, 2, 0, 3, 2, 2, 0, 2, 3, 1, 2, 1, 0, 2, 1, 1, 1,
#        2, 1, 1, 1, 0, 3, 0, 3, 2, 2, 2, 2, 2, 2, 3, 2, 3, 0, 1, 0, 1, 2,
#        0, 1, 1, 0, 3, 0, 3, 2, 0, 0, 0, 1, 1, 2, 2, 2, 2, 1, 2])

# %%
from sklearn.metrics import classification_report
report=classification_report(y_test,yp)
report
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.27      0.34      0.30        44\n           1       0.38      0.38      0.38        45\n           2       0.31      0.40      0.35        47\n           3       0.38      0.20      0.26        59\n\n    accuracy                           0.32       195\n   macro avg       0.33      0.33      0.32       195\nweighted avg       0.33      0.32      0.32       195\n'

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,yp)
cm
# Out:
# array([[15, 11, 12,  6],
#        [11, 17, 13,  4],
#        [11,  7, 19, 10],
#        [19, 10, 18, 12]])

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,yp)
accuracy
# Out:
# 0.3230769230769231
