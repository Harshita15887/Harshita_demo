# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshita15887/Harshita_demo/blob/main/14%5C08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
import pandas as pd
people=['amulya','ramya','siri','sravya']
age=[12,43,16,17]
height=[5.5,5.3,4.9,5.5]
weight=[33,35,45,37]
data ={
    'name':people,
    'Age':age,
    'Height':height,
    'Weight':weight,
}
df=pd.DataFrame(data)
print(df)
# Out:
# ...
#      name  Age  Height  Weight
# 0  amulya   12     5.5      33
# 1   ramya   43     5.3      35
# 2    siri   16     4.9      45
# 3  sravya   17     5.5      37

# %%
# !pip install pandas
import pandas as pd
import matplotlib.pyplot as plt
people=['amulya','ramya','siri','sravya']
age=[12,43,16,17]
height=[5.5,5.3,4.9,5.5]
weight=[33,35,45,37]
data ={
    'name':people,
    'Age':age,
    'Height':height,
    'Weight':weight,
}
df=pd.DataFrame(data)
plt.figure(figsize=(8,6))
plt.scatter(df['Age'],df['Weight'],color='blue',marker='o')
plt.title('Scatter plot of Age distribution')
plt.xlabel('Age(years)')
plt.ylabel('Weight(kg)')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.bar(df['name'],df['Height'],color='green')
plt.title('bar chart of individuals\'heights')
plt.xlabel('name')
plt.ylabel('Height(cm)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.hist(df['Age'],bins=5,color='orange',edgecolor='black')
plt.title('histogram of age distribution')
plt.xlabel('Age(years)')
plt.ylabel('frequency')
plt.show()
